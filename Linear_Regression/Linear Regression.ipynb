# %%
class simepleLR:
  def __init__(self):
    self.m = None
    self.b = None

  def fit(self,X_train,y_train):
    num=0
    den=0
    for i in range(X_train.shape[0]):
      num =num+((X_train[i]-X_train.mean())*(y_train[i]-y_train.mean()))
      den =den+((X_train[i]-X_train.mean())*(X_train[i]-X_train.mean()))

    self.m = num/den
    self.b= y_train.mean()-(self.m*X_train.mean())

    print(self.m)
    print(self.b)


  def predict(self,X_test):

    return self.m*X_test+self.b;

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Machine learning/Linear_Regression/placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=df.iloc[:,0].values
y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
LR = simepleLR()
LR.fit(X_train,y_train)
# Out:
# 0.5579519734250721
# -0.8961119222429152

# %%
print(LR.predict(X_test[4]))
# Out:
# 1.6537285963096644

# %%
X_test
# Out:
# array([8.58, 7.15, 5.88, 6.22, 4.57, 4.79, 5.32, 6.86, 8.35, 6.87, 8.94,
#        7.9 , 6.93, 5.91, 7.32, 7.82, 5.09, 7.42, 6.94, 7.73, 6.19, 7.28,
#        6.73, 7.2 , 8.21, 6.75, 7.87, 7.6 , 8.63, 5.12, 8.15, 7.36, 8.31,
#        6.6 , 6.59, 7.47, 7.93, 6.29, 6.37, 6.47])

# %%
y_test
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
X_train.shape
# Out:
# (160,)

# %%
X_test.shape
# Out:
# (40,)
